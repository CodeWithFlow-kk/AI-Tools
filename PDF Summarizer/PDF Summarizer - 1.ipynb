# %% [markdown]
# # **PDF Summarizer**

# %%
# Install dependencies
# !pip install -q pymupdf transformers sentencepiece accelerate

# %%
# Upload PDF
from google.colab import files

uploaded = files.upload()
pdf_file = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-fd8dec3b-23aa-48c6-86c3-0ac8e3940649" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd8dec3b-23aa-48c6-86c3-0ac8e3940649">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Extract text from PDF
import fitz

doc = fitz.open(pdf_file)

text = ""

for page in doc:
    text += page.get_text()

doc.close()

# %%
# Clean extracted text
text = text.replace("\n", " ")

# %%
# Load model and tokenizer
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "facebook/bart-large-cnn"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# Loading weights:   0%|          | 0/511 [00:00<?, ?it/s]

# %%
# Tokenize input text - change words into numbers that the AI can process
inputs = tokenizer(
    text,
    return_tensors="pt",
    max_length=1024,
    truncation=True
)

# %%
# Generate summary - send the processed tokens to the AI model to create a summary
summary_ids = model.generate(
    inputs["input_ids"],
    max_length=150,
    min_length=50,
    num_beams=4,
    early_stopping=True
)

# %%
# Decode summary - change the AI’s numeric output back into readable sentences
summary = tokenizer.decode(
    summary_ids[0],
    skip_special_tokens=True
)

# %%
import textwrap

# Format summary into readable lines
formatted_summary = textwrap.fill(summary, width=80)

# %%
# Print summary
print("\n===== PDF SUMMARY =====\n")
print(formatted_summary)
# Out:
# ===== PDF SUMMARY =====
#
# Artificial Intelligence has rapidly become one of the most transformative
# technologies of the modern era. From smartphones and virtual assistants to
# healthcare and education, AI is now integrated into many aspects of daily life.
# Despite its advantages, AI raises important concerns. Privacy, job displacement,
# and ethical decision-making are major topics of discussion.
